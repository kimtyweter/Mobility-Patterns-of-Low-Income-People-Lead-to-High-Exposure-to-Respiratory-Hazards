# %%
# Plot Income_Segregation save the file


import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib inline

from matplotlib.pyplot import figure
figure(figsize=(8, 6))
ax = plt.subplot(111)

cm = plt.cm.get_cmap('gnuplot2')

# _, bins, patches = ax.hist(Income_Segregation['Segregation'], density=False ,color="r",bins=50)
_, bins, patches = ax.hist(Income_Segregation['Segregation'], density=False, weights=np.ones_like(Income_Segregation['Segregation']) / len(Income_Segregation['Segregation']) ,color="r",bins=50)


bin_centers = 0.5*(bins[:-1]+bins[1:])
col = bin_centers - min(bin_centers)
col /= max(col)

for c, p in zip(col, patches):
    plt.setp(p, "facecolor", cm(c))


# sns.displot(Income_Segregation['Segregation'], stat='probability', bins = 50)

for spine in plt.gca().spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth('1') 

ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.setp(ax.spines.values(), linewidth=3)

plt.grid(False)

plt.tick_params(bottom = True)
plt.tick_params(left = True)
plt.xticks(fontsize= 24)
plt.yticks(fontsize= 24)
ax.tick_params('both', length = 10, width=2, which='major')

plt.locator_params(axis = "y",nbins=5)
# ax = plt.gca()
# ax.set_ylim([0, 4])



plt.xlabel('Income Segregation',fontname="Arial", fontsize = 24)
plt.ylabel('P(X)',fontname="Arial", fontsize = 24)


plt.savefig('Income_Segregation.pdf', dpi = 300, bbox_inches="tight")
