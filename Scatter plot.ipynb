# %%
####### Version2

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib inline

plt.figure(figsize = (8,6))

# PDF




ax = sns.scatterplot(df_plot["bins"], df_plot["ccdf"], marker = 'o', color = 'steelblue')
ax.set_yscale('log')
ax.set_xscale('log')

ax = sns.scatterplot(df_plot["bins"], df_plot["density"], marker = 'o', color = 'red')
# ax = sns.scatterplot(data = df_plot, x = "n", y = "density", marker = 'o', color = 'red')
ax.set_yscale('log')
ax.set_xscale('log')


plt.xticks(fontsize= 24)
plt.yticks(fontsize= 24)
plt.minorticks_off()

for spine in plt.gca().spines.values():
    spine.set_visible(True)
    spine.set_color('black')
    spine.set_linewidth('1') 

ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.setp(ax.spines.values(), linewidth=3)


import matplotlib.patches as mpatches
a = mpatches.Patch(color='steelblue', label='CCDF', hatch = 'o')
b = mpatches.Patch(color='red', label='PDF', hatch = 'o')

plt.legend(handles=[a,b],fontsize = 24, framealpha=0,facecolor='white', edgecolor = 'black')

plt.grid(False)

plt.tick_params(bottom = True)
plt.tick_params(left = True)




plt.xlabel('Total emissions (ton)',fontname="Arial", fontsize = 24)

plt.ylabel('P(X), P(X ≥ x)', fontname="Arial", fontsize = 24)

plt.savefig('PM2.5 Emissions CCDF.pdf', dpi=300, bbox_inches="tight")
